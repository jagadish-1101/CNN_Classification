# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense , Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
X_train = np.loadtxt('input.csv', delimiter=',')
Y_train = np.loadtxt('labels.csv', delimiter=',')

X_test = np.loadtxt('input_test.csv', delimiter=',')
Y_test = np.loadtxt('labels_test.csv', delimiter=',')

# %%
X_train = X_train.reshape(len(X_train),100,100,3)
Y_train = Y_train.reshape(len(Y_train),1)

X_test = X_test.reshape(len(X_test),100,100,3)
Y_test = Y_test.reshape(len(Y_test),1)

X_train = X_train / 255.0
X_test = X_test / 255.0

#data augmentation to improve training
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2
)

# %%
print("shape of X_train:", X_train.shape)
print("shape of Y_train:", Y_train.shape)
print("shape of X_test:", X_test.shape) 
print("shape of Y_test:", Y_test.shape)
# Out:
# shape of X_train: (2000, 100, 100, 3)
# shape of Y_train: (2000, 1)
# shape of X_test: (400, 100, 100, 3)
# shape of Y_test: (400, 1)

# %%
idx = random.randint(0, len(X_train))
plt.imshow(X_train[idx, :])
plt.show()

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), activation= 'relu', input_shape = (100,100,3))) # 32,64 is the filter
model.add(MaxPooling2D((2,2)))# converting 2d data to 1d data
model.add(Dropout(0.25)) # to remove particular data from the dataset

model.add(Conv2D(64, (3,3), activation= 'relu'))#(3,3) is the size of the filter( hidden layers)
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation = 'sigmoid'))
# Out:
# c:\Users\manda_f9cy9yc\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(datagen.flow(X_train, Y_train, batch_size=32),
          epochs=30,
          validation_data=(X_test, Y_test),
          verbose=1)
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 243ms/step - accuracy: 0.4895 - loss: 0.7228 - val_accuracy: 0.5000 - val_loss: 0.6919
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 18s 291ms/step - accuracy: 0.5115 - loss: 0.6941 - val_accuracy: 0.5000 - val_loss: 0.6917
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 23s 368ms/step - accuracy: 0.5145 - loss: 0.6922 - val_accuracy: 0.5000 - val_loss: 0.6856
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 341ms/step - accuracy: 0.5455 - loss: 0.6894 - val_accuracy: 0.5875 - val_loss: 0.6807
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 328ms/step - accuracy: 0.5440 - loss: 0.6869 - val_accuracy: 0.5675 - val_loss: 0.6872
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 18s 289ms/step - accuracy: 0.5375 - loss: 0.6873 - val_accuracy: 0.5825 - val_loss: 0.6732
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 19s 295ms/step - accuracy: 0.5775 - loss: 0.6831 - val_accuracy: 0.6025 - val_loss: 0.6764
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 19s 298ms/step - accuracy: 0.5625 - loss: 0.6808 - val_accuracy: 0.6025 - val_loss: 0.6680
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 311ms/step - accuracy: 0.5660 - loss: 0.6805 - val_accuracy: 0.5800 - val_loss: 0.6681
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 339ms/step - accuracy: 0.5830 - loss: 0.6629 - val_accuracy: 0.6550 - val_loss: 0.6396
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 30s 475ms/step - accuracy: 0.5900 - loss: 0.6591 - val_accuracy: 0.6225 - val_loss: 0.6560
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 314ms/step - accuracy: 0.5920 - loss: 0.6529 - val_accuracy: 0.6025 - val_loss: 0.6543
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 335ms/step - accuracy: 0.6105 - loss: 0.6541 - val_accuracy: 0.6350 - val_loss: 0.6352
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 18s 294ms/step - accuracy: 0.6075 - loss: 0.6519 - val_accuracy: 0.6675 - val_loss: 0.6295
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 337ms/step - accuracy: 0.6265 - loss: 0.6456 - val_accuracy: 0.5725 - val_loss: 0.6547
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 271ms/step - accuracy: 0.6205 - loss: 0.6480 - val_accuracy: 0.7100 - val_loss: 0.6011
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 15s 235ms/step - accuracy: 0.6535 - loss: 0.6249 - val_accuracy: 0.6950 - val_loss: 0.5934
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 15s 238ms/step - accuracy: 0.6415 - loss: 0.6320 - val_accuracy: 0.7475 - val_loss: 0.5583
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 14s 223ms/step - accuracy: 0.6670 - loss: 0.6077 - val_accuracy: 0.6475 - val_loss: 0.6119
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 15s 240ms/step - accuracy: 0.6710 - loss: 0.6118 - val_accuracy: 0.7300 - val_loss: 0.5578
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 15s 236ms/step - accuracy: 0.6875 - loss: 0.5981 - val_accuracy: 0.7300 - val_loss: 0.5495
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 15s 241ms/step - accuracy: 0.6920 - loss: 0.5994 - val_accuracy: 0.7200 - val_loss: 0.5653
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 15s 231ms/step - accuracy: 0.6855 - loss: 0.5902 - val_accuracy: 0.7275 - val_loss: 0.5401
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 15s 231ms/step - accuracy: 0.6895 - loss: 0.5808 - val_accuracy: 0.7500 - val_loss: 0.5338
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 15s 234ms/step - accuracy: 0.6890 - loss: 0.5906 - val_accuracy: 0.7400 - val_loss: 0.5456
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 15s 233ms/step - accuracy: 0.7170 - loss: 0.5647 - val_accuracy: 0.7500 - val_loss: 0.5239
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 15s 230ms/step - accuracy: 0.7130 - loss: 0.5677 - val_accuracy: 0.7600 - val_loss: 0.5227
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 15s 235ms/step - accuracy: 0.7075 - loss: 0.5702 - val_accuracy: 0.7275 - val_loss: 0.5366
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 15s 236ms/step - accuracy: 0.7165 - loss: 0.5549 - val_accuracy: 0.7625 - val_loss: 0.4957
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 19s 295ms/step - accuracy: 0.6985 - loss: 0.5722 - val_accuracy: 0.7900 - val_loss: 0.4925

# %%
model.evaluate(X_test, Y_test)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.7900 - loss: 0.4925
# [0.49247822165489197, 0.7900000214576721]

# %%
idx2= random.randint(0, len(Y_test))
plt.imshow(X_test[idx2, :])
plt.show()

y_pred = model.predict(X_test[idx2, :].reshape(1,100,100,3))
y_pred = y_pred > 0.5

if(y_pred == 0):
    pred = "dog"

else: 
    pred = 'cat'

print("The model prediction is", pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# The model prediction is dog

# %%
model.save('model.h5')
print('our model is saved')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# our model is saved
